# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('all_races.csv')
# Out:
# /Users/vascobartolomeu/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (0,2,3,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
x = df.iloc[:,3:12].sort_values(['bib', 'event'],ascending = [True,False])

# %%
x.loc[x['bib'] == 1]
# Out:
#        bib                 name sex nation              team  \
# 102010   1      Rui Pedro Silva   M     PT        Individual
# 105759   1      Rui Pedro Silva   M     PT       S L Benfica
# 110634   1      Rui Pedro Silva   M     PT       S L Benfica
# 118472   1      Rui Pedro Silva   M     PT       S L Benfica
# 127446   1         Jose Azevedo   M     PT               NaN
# 248940   1      Rui Pedro Silva   M     PT        Individual
# 252689   1      Rui Pedro Silva   M     PT       S L Benfica
# 257564   1      Rui Pedro Silva   M     PT       S L Benfica
# 265402   1      Rui Pedro Silva   M     PT       S L Benfica
# 274376   1         Jose Azevedo   M     PT               NaN
# 285072   1         Rui Teixeira   M     PT      Sporting C P
# 85923    1      Rui Pedro Silva   M     PT        Individual
# 88423    1      Rui Pedro Silva   M     PT       S L Benfica
# 95810    1      Rui Pedro Silva   M     PT       S L Benfica
# ...
